# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3
# Out:
# ...
#      |████████████████████████████████| 1.3MB 14.7MB/s
# ...
#      |████████████████████████████████| 133kB 47.7MB/s
# ...
#      |████████████████████████████████| 194kB 46.9MB/s
# ...
#      |████████████████████████████████| 133kB 48.9MB/s
# ...
#      |████████████████████████████████| 7.7MB 43.6MB/s
# ...
#      |████████████████████████████████| 81kB 11.3MB/s
# ...
#      |████████████████████████████████| 143kB 58.2MB/s
# ...
# ERROR: requests 2.23.0 has requirement urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you'll have urllib3 1.26.6 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
import time
import torch
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# Tesla V100-SXM2-16GB

# %%
# !python3 "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/bin/run_bert_tagger.py" \
--data_sign resume_ner \
--config_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/bert.json" \
--data_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/ner/resume" \
--output_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/resume_ner bert.bin" \
--bert_model "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12" \
--task_name ner \
--max_seq_length 150 \
--do_train \
--seed 9165 \
--do_eval \
--train_batch_size 32 \
--dev_batch_size 32 \
--test_batch_size 32 \
--learning_rate 3e-5 \
--num_train_epochs 5 \
--checkpoint 100
# Out:
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PRINT default FONT PATH
# ********************
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/fonts
# ********************
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# {
#   "bert_frozen": "false",
#   "hidden_size": 768,
#   "hidden_dropout_prob": 0.1,
#   "classifier_sign": "single_linear",
#   "clip_grad": 1.0,
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
# ...

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 00:04:31
